# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("E:\\For_Job\\Internship_Ineuron\\Air_Quality_Index\Code\\notebook\\data\\waqi-covid19-airqualitydata-2015H1.csv",sep=",",skiprows=4)

# %%
data.head()
# Out:
#          Date Country    City Specie  count  min   max  median  variance
# 0  2015-01-06      KR  Jeonju     co    124  0.1  12.3     4.5     55.74
# 1  2015-01-22      KR  Jeonju     co    116  4.5  10.0     6.7     16.09
# 2  2015-03-30      KR  Jeonju     co    118  1.2  11.2     5.6     35.98
# 3  2015-05-27      KR  Jeonju     co     93  2.3   5.6     3.4      6.54
# 4  2015-02-03      KR  Jeonju     co    133  4.5  13.4     7.8     39.24

# %%
data['Specie'].value_counts()
# Out:
# Specie
# no2       70202
# pm10      68869
# o3        68478
# pm25      64321
# so2       58839
# co        52354
# aqi        2707
# uvi        2281
# neph        564
# mepaqi      189
# psi         176
# Name: count, dtype: int64

# %%
data.head()
# Out:
#          Date Country    City Specie  count  min   max  median  variance
# 0  2015-01-06      KR  Jeonju     co    124  0.1  12.3     4.5     55.74
# 1  2015-01-22      KR  Jeonju     co    116  4.5  10.0     6.7     16.09
# 2  2015-03-30      KR  Jeonju     co    118  1.2  11.2     5.6     35.98
# 3  2015-05-27      KR  Jeonju     co     93  2.3   5.6     3.4      6.54
# 4  2015-02-03      KR  Jeonju     co    133  4.5  13.4     7.8     39.24

# %%
pd.to_datetime(data['Date']).dt.day_name()
# Out:
# 0           Tuesday
# 1          Thursday
# 2            Monday
# 3         Wednesday
# 4           Tuesday
#             ...
# 388975       Friday
# 388976     Saturday
# 388977     Saturday
# 388978       Sunday
# 388979       Friday
# Name: Date, Length: 388980, dtype: object

# %%
stock_data = data.set_index('Date')

# %%
stock_data
# Out:
#            Country    City Specie  count  min   max  median  variance
# Date
# 2015-01-06      KR  Jeonju     co    124  0.1  12.3     4.5     55.74
# 2015-01-22      KR  Jeonju     co    116  4.5  10.0     6.7     16.09
# 2015-03-30      KR  Jeonju     co    118  1.2  11.2     5.6     35.98
# 2015-05-27      KR  Jeonju     co     93  2.3   5.6     3.4      6.54
# 2015-02-03      KR  Jeonju     co    133  4.5  13.4     7.8     39.24
# ...            ...     ...    ...    ...  ...   ...     ...       ...
# 2015-06-05      MK  Skopje    no2     72  1.3  22.7     4.0    288.64
# 2015-04-25      MK  Skopje    no2     71  1.3  27.7     4.4    384.63
# 2015-05-16      MK  Skopje    no2     72  1.0  23.1     6.0    319.02
# 2015-05-17      MK  Skopje    no2     69  1.3  19.2     3.8    177.47
# 2015-05-22      MK  Skopje    no2     72  1.0  19.0     7.5    296.18
#
# [388980 rows x 8 columns]

# %%
stock_data=stock_data[['count'	,'min'	,'max',	'median'	,'variance']]

# %%
stock_data.head()
# Out:
#             count  min   max  median  variance
# Date
# 2015-01-06    124  0.1  12.3     4.5     55.74
# 2015-01-22    116  4.5  10.0     6.7     16.09
# 2015-03-30    118  1.2  11.2     5.6     35.98
# 2015-05-27     93  2.3   5.6     3.4      6.54
# 2015-02-03    133  4.5  13.4     7.8     39.24

# %%
stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 388980 entries, 2015-01-06 to 2015-05-22
# Data columns (total 5 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   count     388980 non-null  int64
#  1   min       388980 non-null  float64
#  2   max       388980 non-null  float64
#  3   median    388980 non-null  float64
#  4   variance  388980 non-null  float64
# dtypes: float64(4), int64(1)
# memory usage: 17.8+ MB

# %%
plt.plot(sorted(stock_data.variance))

# %%
plt.style.use('ggplot')
plt.figure(figsize=(18,8))
plt.grid(True)
plt.xlabel("Dates",fontsize=30)
plt.ylabel("Closed stock",fontsize=30)
plt.plot(sorted(stock_data['variance']))
plt.title("Tesla closing price",fontsize=30)
plt.show()

# %%
data.head()
# Out:
#          Date Country    City Specie  count  min   max  median  variance
# 0  2015-01-06      KR  Jeonju     co    124  0.1  12.3     4.5     55.74
# 1  2015-01-22      KR  Jeonju     co    116  4.5  10.0     6.7     16.09
# 2  2015-03-30      KR  Jeonju     co    118  1.2  11.2     5.6     35.98
# 3  2015-05-27      KR  Jeonju     co     93  2.3   5.6     3.4      6.54
# 4  2015-02-03      KR  Jeonju     co    133  4.5  13.4     7.8     39.24

# %%
data[data.Specie=='co']
# Out:
#               Date Country    City Specie  count  min   max  median  variance
# 0       2015-01-06      KR  Jeonju     co    124  0.1  12.3     4.5     55.74
# 1       2015-01-22      KR  Jeonju     co    116  4.5  10.0     6.7     16.09
# 2       2015-03-30      KR  Jeonju     co    118  1.2  11.2     5.6     35.98
# 3       2015-05-27      KR  Jeonju     co     93  2.3   5.6     3.4      6.54
# 4       2015-02-03      KR  Jeonju     co    133  4.5  13.4     7.8     39.24
# ...            ...     ...     ...    ...    ...  ...   ...     ...       ...
# 388590  2015-05-06      MK  Skopje     co    143  0.7  12.1     3.5     41.97
# 388591  2015-05-13      MK  Skopje     co    141  0.2  11.9     3.6     55.74
# 388592  2015-05-14      MK  Skopje     co    141  0.1   9.4     3.6     52.93
# 388593  2015-05-29      MK  Skopje     co     91  0.1   6.3     2.9     25.43
# 388594  2015-06-28      MK  Skopje     co    101  0.1   7.0     1.9     12.03
#
# [52354 rows x 9 columns]

# %%
data['day_of_year']=pd.to_datetime(data.Date).dt.day_of_year.sort_values(ascending=True)
data['month_year']=pd.to_datetime(data.Date).dt.month
data['year']=pd.to_datetime(data.Date).dt.year
data['day_of_month']=pd.to_datetime(data.Date).dt.day

# %%
data.head()
# Out:
#          Date Country    City Specie  count  min   max  median  variance  \
# 0  2015-01-06      KR  Jeonju     co    124  0.1  12.3     4.5     55.74
# 1  2015-01-22      KR  Jeonju     co    116  4.5  10.0     6.7     16.09
# 2  2015-03-30      KR  Jeonju     co    118  1.2  11.2     5.6     35.98
# 3  2015-05-27      KR  Jeonju     co     93  2.3   5.6     3.4      6.54
# 4  2015-02-03      KR  Jeonju     co    133  4.5  13.4     7.8     39.24
#
#    day_of_year  month_year  year  day_of_month
# 0            6           1  2015             6
# 1           22           1  2015            22
# 2           89           3  2015            30
# 3          147           5  2015            27
# 4           34           2  2015             3

# %%
data[(data.day_of_year==5) & (data.City=='Jeonju')]
# Out:
#            Date Country    City Specie  count  min   max  median  variance  \
# 174  2015-01-05      KR  Jeonju     co    141  3.4  25.6     7.8    116.49
# 216  2015-01-05      KR  Jeonju   pm10    188  1.0  88.0    57.0   2707.08
# 689  2015-01-05      KR  Jeonju    so2     86  1.5  17.2     8.6    129.48
# 899  2015-01-05      KR  Jeonju    no2    185  2.8  66.4    22.3   1491.77
# 951  2015-01-05      KR  Jeonju   pm25      8  2.0   5.0     3.0      9.82
#
#      day_of_year  month_year  year  day_of_month
# 174            5           1  2015             5
# 216            5           1  2015             5
# 689            5           1  2015             5
# 899            5           1  2015             5
# 951            5           1  2015             5

# %%
# Out:
# 3188440.0

# %%
data[data.variance==max(data.variance)]
# Out:
#              Date Country        City Specie  count   min    max  median  \
# 29423  2015-04-17      NL  Maastricht   pm25      3  17.0  999.0    25.0
#
#         variance  day_of_year  month_year  year  day_of_month
# 29423  3188440.0          107           4  2015            17

# %%
data.head()
# Out:
#          Date Country    City Specie  count  min   max  median  variance  \
# 0  2015-01-06      KR  Jeonju     co    124  0.1  12.3     4.5     55.74
# 1  2015-01-22      KR  Jeonju     co    116  4.5  10.0     6.7     16.09
# 2  2015-03-30      KR  Jeonju     co    118  1.2  11.2     5.6     35.98
# 3  2015-05-27      KR  Jeonju     co     93  2.3   5.6     3.4      6.54
# 4  2015-02-03      KR  Jeonju     co    133  4.5  13.4     7.8     39.24
#
#    day_of_year  month_year  year  day_of_month
# 0            6           1  2015             6
# 1           22           1  2015            22
# 2           89           3  2015            30
# 3          147           5  2015            27
# 4           34           2  2015             3

# %%
data.nunique()
# Out:
# Date               189
# Country             58
# City               470
# Specie              11
# count             1951
# min                783
# max               3014
# median            1114
# variance        188376
# day_of_year        189
# month_year           8
# year                 2
# day_of_month        31
# dtype: int64

# %%
plt.figure(figsize=(12,8))
plt.xticks(rotation=90)
kr_data = data[(data.Country=='IN')&(data.Specie=='pm25')]
sns.barplot(x='City',y='max',data=kr_data,legend='brief')
# Out:
# <Axes: xlabel='City', ylabel='max'>

# %%
data.Specie.value_counts()
# Out:
# Specie
# no2       70202
# pm10      68869
# o3        68478
# pm25      64321
# so2       58839
# co        52354
# aqi        2707
# uvi        2281
# neph        564
# mepaqi      189
# psi         176
# Name: count, dtype: int64

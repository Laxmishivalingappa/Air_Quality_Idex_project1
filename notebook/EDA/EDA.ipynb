# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %%
from sklearn.preprocessing import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# e:\For_Job\Internship_Ineuron\Air_Quality_Index\Code\notebook\EDA\EDA.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/e%3A/For_Job/Internship_Ineuron/Air_Quality_Index/Code/notebook/EDA/EDA.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> from sklearn.preprocessing import train_test_split
#
# ImportError: cannot import name 'train_test_split' from 'sklearn.preprocessing' (e:\For_Job\Internship_Ineuron\Air_Quality_Index\Code\venv\lib\site-packages\sklearn\preprocessing\__init__.py)

# %%
pip install ipykernel
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data = pd.read_csv("E:\\For_Job\\Internship_Ineuron\\Air_Quality_Index\Code\\notebook\\data\\waqi-covid19-airqualitydata-2023.csv",sep="\t",skiprows=4)

# %%
data = pd.read_csv("E:\\For_Job\\Internship_Ineuron\\Air_Quality_Index\Code\\notebook\\data\\waqi-covid19-airqualitydata-2015H1.csv",sep=",",skiprows=4)

# %%
data.head()
# Out:
#          Date Country    City Specie  count  min   max  median  variance
# 0  2015-01-06      KR  Jeonju     co    124  0.1  12.3     4.5     55.74
# 1  2015-01-22      KR  Jeonju     co    116  4.5  10.0     6.7     16.09
# 2  2015-03-30      KR  Jeonju     co    118  1.2  11.2     5.6     35.98
# 3  2015-05-27      KR  Jeonju     co     93  2.3   5.6     3.4      6.54
# 4  2015-02-03      KR  Jeonju     co    133  4.5  13.4     7.8     39.24

# %%
data.shape
# Out:
# (388980, 9)

# %%
data.columns
# Out:
# Index(['Date', 'Country', 'City', 'Specie', 'count', 'min', 'max', 'median',
#        'variance'],
#       dtype='object')

# %%
data.Specie.value_counts()
# Out:
# Specie
# no2       70202
# pm10      68869
# o3        68478
# pm25      64321
# so2       58839
# co        52354
# aqi        2707
# uvi        2281
# neph        564
# mepaqi      189
# psi         176
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388980 entries, 0 to 388979
# Data columns (total 9 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Date      388980 non-null  object
#  1   Country   388980 non-null  object
#  2   City      388980 non-null  object
#  3   Specie    388980 non-null  object
#  4   count     388980 non-null  int64
#  5   min       388980 non-null  float64
#  6   max       388980 non-null  float64
#  7   median    388980 non-null  float64
#  8   variance  388980 non-null  float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 26.7+ MB

# %%
data.nunique()
# Out:
# Date           189
# Country         58
# City           470
# Specie          11
# count         1951
# min            783
# max           3014
# median        1114
# variance    188376
# dtype: int64

# %%
sns.pairplot(data=data)

# %%
plt.figure(figsize=(15,10))
plt.xticks(rotation=90)
data.Country.hist()
plt.plot()
# Out:
# []

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data[(data['Date']=='2015-01-22') | (data['Date']=='2016-01-22') & (data['City']=='Jeonju') ]
# Out:
#               Date Country    City Specie  count   min    max  median  \
# 1       2015-01-22      KR  Jeonju     co    116   4.5   10.0     6.7
# 357     2015-01-22      KR  Jeonju   pm10    159  10.0  128.0    53.0
# 469     2015-01-22      KR  Jeonju     o3    137   0.8   30.4    10.4
# 716     2015-01-22      KR  Jeonju    so2     79   4.3   12.9     8.6
# 782     2015-01-22      KR  Jeonju    no2    159   3.8   41.7    22.3
# ...            ...     ...     ...    ...    ...   ...    ...     ...
# 387702  2015-01-22      AT  Vienna   pm25    163  30.0   93.0    63.0
# 387900  2015-01-22      AT    Graz     co     64   0.1    0.1     0.1
# 387953  2015-01-22      AT    Graz   pm10    239  13.0  147.0    37.0
# 388200  2015-01-22      AT    Graz    so2     54   0.6    4.6     1.6
# 388391  2015-01-22      AT    Graz    no2    210   7.8   26.1    15.6
#
#         variance
# 1          16.09
# 357      1875.21
# 469       457.52
# 716        45.48
# 782       978.73
# ...

# %%
pip install geopandas
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ...
#      ---------------------------------------- 0.0/51.1 kB ? eta -:--:--
#      -------------------------------- ------- 41.0/51.1 kB ? eta -:--:--
#      -------------------------------- ------- 41.0/51.1 kB ? eta -:--:--
#      -------------------------------- ------- 41.0/51.1 kB ? eta -:--:--
#      -------------------------------- ------- 41.0/51.1 kB ? eta -:--:--
#      -------------------------------------- 51.1/51.1 kB 237.6 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/5.1 MB ? eta -:--:--
#      ---------------------------------------- 0.1/5.1 MB 1.7 MB/s eta 0:00:04
#      - -------------------------------------- 0.2/5.1 MB 2.4 MB/s eta 0:00:03
#      --- ------------------------------------ 0.4/5.1 MB 3.1 MB/s eta 0:00:02
#      ------ --------------------------------- 0.8/5.1 MB 4.1 MB/s eta 0:00:02
#      ------- -------------------------------- 1.0/5.1 MB 4.2 MB/s eta 0:00:01
# ...

# %%
data= data.set_index('Date')

# %%
data.head()
# Out:
#            Country    City Specie  count  min   max  median  variance
# Date
# 2015-01-06      KR  Jeonju     co    124  0.1  12.3     4.5     55.74
# 2015-01-22      KR  Jeonju     co    116  4.5  10.0     6.7     16.09
# 2015-03-30      KR  Jeonju     co    118  1.2  11.2     5.6     35.98
# 2015-05-27      KR  Jeonju     co     93  2.3   5.6     3.4      6.54
# 2015-02-03      KR  Jeonju     co    133  4.5  13.4     7.8     39.24

# %%
data['count'].rolling(5).mean()
# Out:
# Date
# 2015-01-06      NaN
# 2015-01-22      NaN
# 2015-03-30      NaN
# 2015-05-27      NaN
# 2015-02-03    116.8
#               ...
# 2015-06-05     70.8
# 2015-04-25     71.0
# 2015-05-16     71.4
# 2015-05-17     70.8
# 2015-05-22     71.2
# Name: count, Length: 388980, dtype: float64

# %%
import os

# %%
Path= "e:\\For_Job\\Internship_Ineuron\\Air_Quality_Index\\Code\\notebook\\data"

# %%
data_list = []

# %%
os.listdir(Path)
# Out:
# ['waqi-covid19-airqualitydata-2015H1.csv',
#  'waqi-covid19-airqualitydata-2016H1.csv',
#  'waqi-covid19-airqualitydata-2017H1.csv',
#  'waqi-covid19-airqualitydata-2018H1.csv',
#  'waqi-covid19-airqualitydata-2019Q1.csv',
#  'waqi-covid19-airqualitydata-2019Q2.csv',
#  'waqi-covid19-airqualitydata-2019Q3.csv',
#  'waqi-covid19-airqualitydata-2019Q4.csv',
#  'waqi-covid19-airqualitydata-2020Q1.csv',
#  'waqi-covid19-airqualitydata-2020Q2.csv',
#  'waqi-covid19-airqualitydata-2020Q3.csv',
#  'waqi-covid19-airqualitydata-2020Q4.csv',
#  'waqi-covid19-airqualitydata-2021Q1.csv',
#  'waqi-covid19-airqualitydata-2021Q2.csv',
#  'waqi-covid19-airqualitydata-2021Q3.csv',
#  'waqi-covid19-airqualitydata-2021Q4.csv',
#  'waqi-covid19-airqualitydata-2023.csv']

# %%
for i in os.listdir(Path):
    if i.endswith(".csv"):
        file_name = os.path.join(Path,i)
        df = pd.read_csv(file_name,sep=",",skiprows=4)
        data_list.append(df)


data_1 = pd.concat(data_list,ignore_index=True)
data_1.head()
# Out:
#          Date Country    City Specie  count  min   max  median  variance
# 0  2015-01-06      KR  Jeonju     co    124  0.1  12.3     4.5     55.74
# 1  2015-01-22      KR  Jeonju     co    116  4.5  10.0     6.7     16.09
# 2  2015-03-30      KR  Jeonju     co    118  1.2  11.2     5.6     35.98
# 3  2015-05-27      KR  Jeonju     co     93  2.3   5.6     3.4      6.54
# 4  2015-02-03      KR  Jeonju     co    133  4.5  13.4     7.8     39.24

# %%
data_1.shape
# Out:
# (24976854, 9)

# %%
data_1.isna().sum()
# Out:
# Date        0
# Country     0
# City        0
# Specie      0
# count       0
# min         0
# max         0
# median      0
# variance    0
# dtype: int64

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24976854 entries, 0 to 24976853
# Data columns (total 9 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   Date      object
#  1   Country   object
#  2   City      object
#  3   Specie    object
#  4   count     int64
#  5   min       float64
#  6   max       float64
#  7   median    float64
#  8   variance  float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 1.7+ GB

# %%
data_1.Date
# Out:
# 0           2015-01-06
# 1           2015-01-22
# 2           2015-03-30
# 3           2015-05-27
# 4           2015-02-03
#                ...
# 24976849    2022-12-04
# 24976850    2023-01-24
# 24976851    2023-02-12
# 24976852    2023-10-04
# 24976853    2023-10-06
# Name: Date, Length: 24976854, dtype: object

# %%
data_1['Date_conversion']= pd.to_datetime(data_1['Date'])

# %%
data_1.Date_conversion.dtype
# Out:
# dtype('<M8[ns]')

# %%
data_1.Date_conversion.dt.day_of_year.sort_values(ascending=True)
# Out:
# 6321457       1
# 20795282      1
# 2157072       1
# 19326007      1
# 4033502       1
#            ...
# 963511      366
# 19279889    366
# 19014626    366
# 6527635     366
# 6561740     366
# Name: Date_conversion, Length: 24976854, dtype: int32

# %%
data_1.Date_conversion.dt.year.sort_values(ascending=True)
# Out:
# 300829      2014
# 12723195    2014
# 12581064    2014
# 12862771    2014
# 187346      2014
#             ...
# 12145289    2023
# 12145284    2023
# 12145283    2023
# 12145278    2023
# 24976853    2023
# Name: Date_conversion, Length: 24976854, dtype: int32

# %%
data_1[data_1['Date']=='2015-01-06']
# Out:
#                 Date Country    City Specie  count   min    max  median  \
# 0         2015-01-06      KR  Jeonju     co    124   0.1   12.3     4.5
# 252       2015-01-06      KR  Jeonju   pm10    171   1.0  122.0    36.0
# 619       2015-01-06      KR  Jeonju    so2    112   1.5   18.6     7.2
# 774       2015-01-06      KR  Jeonju    no2    172   1.9   37.1    10.2
# 1178      2015-01-06      KR   Seoul    so2   1436   1.5   17.2     7.2
# ...              ...     ...     ...    ...    ...   ...    ...     ...
# 12876080  2015-01-06      AT  Vienna   pm25    129  17.0   99.0    59.0
# 12876317  2015-01-06      AT    Graz     co     58   0.1    0.1     0.1
# 12876555  2015-01-06      AT    Graz   pm10    228   2.0   59.0    17.0
# 12876720  2015-01-06      AT    Graz    so2     68   0.6    9.7     1.6
# 12876807  2015-01-06      AT    Graz    no2    208   1.0   44.4    12.6
#
#           variance Date_conversion
# 0            55.74      2015-01-06
# ...

# %%
data_1[(data_1['Date']=='2015-01-22') & (data_1['City']=='Jeonju') ].duplicated()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\For_Job\Internship_Ineuron\Air_Quality_Index\Code\notebook\EDA\EDA.ipynb Cell 37 line 1
# ----> <a href='vscode-notebook-cell:/e%3A/For_Job/Internship_Ineuron/Air_Quality_Index/Code/notebook/EDA/EDA.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> data_1[(data_1['Date']=='2015-01-22') & (data_1['City']=='Jeonju') ].duplicated()
#
# NameError: name 'data_1' is not defined

# %%
data.Date
# Out:
# 0         2015-01-06
# 1         2015-01-22
# 2         2015-03-30
# 3         2015-05-27
# 4         2015-02-03
#              ...
# 388975    2015-06-05
# 388976    2015-04-25
# 388977    2015-05-16
# 388978    2015-05-17
# 388979    2015-05-22
# Name: Date, Length: 388980, dtype: object

# %%
data.isna().sum()
# Out:
# Date        0
# Country     0
# City        0
# Specie      0
# count       0
# min         0
# max         0
# median      0
# variance    0
# dtype: int64

# %%
data_2023 = pd.read_csv("E:\\For_Job\\Internship_Ineuron\\Air_Quality_Index\Code\\notebook\\data\\waqi-covid19-airqualitydata-2023.csv",sep=",",skiprows=4)

# %%
data_2023.head()
# Out:
#          Date Country    City Specie  count  min  max  median  variance
# 0  2022-04-07      IE  Dublin    so2     17  1.1  1.9     1.6      0.41
# 1  2022-07-15      IE  Dublin    so2      2  0.1  0.2     0.1      0.05
# 2  2022-07-27      IE  Dublin    so2     13  0.1  0.3     0.2      0.04
# 3  2022-11-07      IE  Dublin    so2     18  0.6  1.3     1.0      0.23
# 4  2022-11-23      IE  Dublin    so2     20  0.9  1.8     1.3      0.55

# %%
data_2023.isna().sum()
# Out:
# Date        0
# Country     0
# City        0
# Specie      0
# count       0
# min         0
# max         0
# median      0
# variance    0
# dtype: int64

# %%
#data_2023['date_final']=pd.to_datetime(data_2023['Date'])

# %%
data_2023['date_final'].dt.dayofyear
# Out:
# 0           97
# 1          196
# 2          208
# 3          311
# 4          327
#           ...
# 3906811    338
# 3906812     24
# 3906813     43
# 3906814    277
# 3906815    279
# Name: date_final, Length: 3906816, dtype: int32

# %%
pd.to_datetime(data_2023['Date'])
# Out:
# 0         2022-04-07
# 1         2022-07-15
# 2         2022-07-27
# 3         2022-11-07
# 4         2022-11-23
#              ...
# 3906811   2022-12-04
# 3906812   2023-01-24
# 3906813   2023-02-12
# 3906814   2023-10-04
# 3906815   2023-10-06
# Name: Date, Length: 3906816, dtype: datetime64[ns]

# %%
data.head()
# Out:
#            Country    City Specie  count  min   max  median  variance
# Date
# 2015-01-06      KR  Jeonju     co    124  0.1  12.3     4.5     55.74
# 2015-01-22      KR  Jeonju     co    116  4.5  10.0     6.7     16.09
# 2015-03-30      KR  Jeonju     co    118  1.2  11.2     5.6     35.98
# 2015-05-27      KR  Jeonju     co     93  2.3   5.6     3.4      6.54
# 2015-02-03      KR  Jeonju     co    133  4.5  13.4     7.8     39.24

# %%
data = pd.read_csv("E:\\For_Job\\Internship_Ineuron\\Air_Quality_Index\Code\\notebook\\data\\waqi-covid19-airqualitydata-2015H1.csv",sep=",",skiprows=4)

# %%
data.head()
# Out:
#          Date Country    City Specie  count  min   max  median  variance
# 0  2015-01-06      KR  Jeonju     co    124  0.1  12.3     4.5     55.74
# 1  2015-01-22      KR  Jeonju     co    116  4.5  10.0     6.7     16.09
# 2  2015-03-30      KR  Jeonju     co    118  1.2  11.2     5.6     35.98
# 3  2015-05-27      KR  Jeonju     co     93  2.3   5.6     3.4      6.54
# 4  2015-02-03      KR  Jeonju     co    133  4.5  13.4     7.8     39.24

# %%
data[(data['Date']=='2015-01-06') & (data['City']=="Jeonju")]
# Out:
#            Date Country    City Specie  count  min    max  median  variance
# 0    2015-01-06      KR  Jeonju     co    124  0.1   12.3     4.5     55.74
# 252  2015-01-06      KR  Jeonju   pm10    171  1.0  122.0    36.0   3658.19
# 619  2015-01-06      KR  Jeonju    so2    112  1.5   18.6     7.2     93.64
# 774  2015-01-06      KR  Jeonju    no2    172  1.9   37.1    10.2    612.51

# %%
data[(data['Date']=='2015-02-08') & (data['City']=="Jeonju")]
# Out:
#             Date Country    City Specie  count   min    max  median  variance
# 163   2015-02-08      KR  Jeonju     co     74   1.2    7.8     3.4     18.32
# 209   2015-02-08      KR  Jeonju   pm10    184  20.0   84.0    52.0   2611.80
# 421   2015-02-08      KR  Jeonju     o3    158   0.8   32.0    22.4    549.44
# 648   2015-02-08      KR  Jeonju    so2    110   1.5   10.0     5.8     48.55
# 799   2015-02-08      KR  Jeonju    no2    172   1.0   32.5     6.5    508.74
# 1040  2015-02-08      KR  Jeonju   pm25     24  61.0  124.0    68.0   2467.81

# %%
trail=data_1[(data_1['Date']=='2015-02-08') | (data_1['Date']=='2016-02-08') & (data_1['City']=="Jeonju")]

# %%
trail.head()
# Out:
#            Date Country    City Specie  count   min   max  median  variance  \
# 163  2015-02-08      KR  Jeonju     co     74   1.2   7.8     3.4     18.32
# 209  2015-02-08      KR  Jeonju   pm10    184  20.0  84.0    52.0   2611.80
# 421  2015-02-08      KR  Jeonju     o3    158   0.8  32.0    22.4    549.44
# 648  2015-02-08      KR  Jeonju    so2    110   1.5  10.0     5.8     48.55
# 799  2015-02-08      KR  Jeonju    no2    172   1.0  32.5     6.5    508.74
#
#     Date_conversion
# 163      2015-02-08
# 209      2015-02-08
# 421      2015-02-08
# 648      2015-02-08
# 799      2015-02-08

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lr=LabelEncoder()

# %%
lr.fit_transform(trail['Specie'])
# Out:
# array([1, 6, 5, ..., 5, 9, 7])

# %%
trail[['Specie',	'count',	'min'	,'max',	'median',	'variance']].set_axis(labels=trail['Specie'])
# Out:
#        Specie  count   min    max  median  variance
# Specie
# co         co     74   1.2    7.8     3.4     18.32
# pm10     pm10    184  20.0   84.0    52.0   2611.80
# o3         o3    158   0.8   32.0    22.4    549.44
# so2       so2    110   1.5   10.0     5.8     48.55
# no2       no2    172   1.0   32.5     6.5    508.74
# ...       ...    ...   ...    ...     ...       ...
# co         co    123   2.3   10.0     5.6     27.24
# pm10     pm10    170  21.0   96.0    45.0   4174.06
# o3         o3    177   4.0   66.1    29.6   3056.52
# so2       so2    108   2.9   28.6    11.5    261.96
# pm25     pm25     67  70.0  170.0   107.0  11695.10
#
# [4052 rows x 6 columns]

# %%
trail.reset_index()
# Out:
#          index        Date Country    City Specie  count   min    max  median  \
# 0          163  2015-02-08      KR  Jeonju     co     74   1.2    7.8     3.4
# 1          209  2015-02-08      KR  Jeonju   pm10    184  20.0   84.0    52.0
# 2          421  2015-02-08      KR  Jeonju     o3    158   0.8   32.0    22.4
# 3          648  2015-02-08      KR  Jeonju    so2    110   1.5   10.0     5.8
# 4          799  2015-02-08      KR  Jeonju    no2    172   1.0   32.5     6.5
# ...        ...         ...     ...     ...    ...    ...   ...    ...     ...
# 4047  13269712  2016-02-08      KR  Jeonju     co    123   2.3   10.0     5.6
# 4048  13269974  2016-02-08      KR  Jeonju   pm10    170  21.0   96.0    45.0
# 4049  13270028  2016-02-08      KR  Jeonju     o3    177   4.0   66.1    29.6
# 4050  13270178  2016-02-08      KR  Jeonju    so2    108   2.9   28.6    11.5
# 4051  13270519  2016-02-08      KR  Jeonju   pm25     67  70.0  170.0   107.0
#
#       variance Date_conversion
# ...

# %%
pd.get_dummies(trail['Specie'])
# Out:
#             aqi     co  mepaqi   neph    no2     o3   pm10   pm25    psi  \
# 163       False   True   False  False  False  False  False  False  False
# 209       False  False   False  False  False  False   True  False  False
# 421       False  False   False  False  False   True  False  False  False
# 648       False  False   False  False  False  False  False  False  False
# 799       False  False   False  False   True  False  False  False  False
# ...         ...    ...     ...    ...    ...    ...    ...    ...    ...
# 13269712  False   True   False  False  False  False  False  False  False
# 13269974  False  False   False  False  False  False   True  False  False
# 13270028  False  False   False  False  False   True  False  False  False
# 13270178  False  False   False  False  False  False  False  False  False
# 13270519  False  False   False  False  False  False  False   True  False
#
#             so2    uvi
# 163       False  False
# 209       False  False
# ...
